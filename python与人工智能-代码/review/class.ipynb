# %%
# 定义Student类，具有name和score属性，以及打印成绩方法
class Student(object):
    def __init__(self,name,score):
        self.__name = name
        self.__score = score
    
    def print_score(self):
        print('{}: {}'.format(self._Student__name,self._Student__score))

# 测试案例
s1 = Student("Alice", 88)
s2 = Student("Bob", 92)
s1.print_score()  # Alice: 88
s2.print_score()  # Bob: 92
# Out:
# Alice: 88
# Bob: 92

# %%
s3 = Student('a',100)
s3.score = 1
print(s3._Student__score)
s2.aaa = 1
print(s2.aaa)
# Out:
# 100
# 1
