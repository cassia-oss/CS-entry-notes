# %%
str=input('请输入:')
print(str)
# Out:
# 人工智能与python程序涉及

# %%
print('Hello AI!')
# Out:
# Hello AI!

# %%
import os

# %%
print(os.path)
# Out:
# <module 'ntpath' (frozen)>

# %%
text_file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')

# %%
print(text_file.readline())
# Out:
# 人工智能与Python程序设计 第一课

# %%
binary_file = open('人工智能与Python程序设计.txt', 'rb')

# %%
print(binary_file.readline())
# Out:
# b'\xe4\xba\xba\xe5\xb7\xa5\xe6\x99\xba\xe8\x83\xbd\xe4\xb8\x8ePython\xe7\xa8\x8b\xe5\xba\x8f\xe8\xae\xbe\xe8\xae\xa1 \xe7\xac\xac\xe4\xb8\x80\xe8\xaf\xbe\n'

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
for i in range(3):
    text = file.readline() #读取当前行
    print(text)
file.close()
# Out:
# 人工智能与Python程序设计 第一课
#
# 人工智能与Python程序设计 第二课
#
# 人工智能与Python程序设计 第三课

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
for i in range(3):
    text = file.readline() #读取当前行
    print(text,end='')
file.close()
# Out:
# 人工智能与Python程序设计 第一课
# 人工智能与Python程序设计 第二课
# 人工智能与Python程序设计 第三课

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
text = file.readlines(-1) #读取文件内所有行
print(text)
file.close()
# Out:
# ['人工智能与Python程序设计 第一课\n', '人工智能与Python程序设计 第二课\n', '人工智能与Python程序设计 第三课\n']

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
text = file.read(-1) #读取当前文件全部字符内容
print(text, end='')
file.close()
# Out:
# 人工智能与Python程序设计 第一课
# 人工智能与Python程序设计 第二课
# 人工智能与Python程序设计 第三课

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
for i in range(3):
    text = file.readline(5) #读取在当前行从当前位置开始5个字符
    print(text)
file.close()
# Out:
# 人工智能与
# Pytho
# n程序设计

# %%
file = open('人工智能与Python程序设计.txt', 'rt', encoding='utf-8')
for i in range(3):
    text = file.readline(5) #读取在当前行从当前位置开始5个字符
    print(text)
    text = file.readline()  #读取在当前行从当前位置开始到结束的所有字符
    print(text)
file.close()
# Out:
# 人工智能与
# Python程序设计 第一课
#
# 人工智能与
# Python程序设计 第二课
#
# 人工智能与
# Python程序设计 第三课

# %%
file_write = open('人工智能与Python程序设计-写入.txt', 'w') # 文件对象的创建与打开
file_write.write('人工智能与Python程序设计 第一课')   # 字符串写入
file_write.close()   # 文件关闭
file_read = open('人工智能与Python程序设计-写入.txt', 'r')  
print(file_read.read())
file_read.close()
# Out:
# 人工智能与Python程序设计 第一课

# %%
file_write = open('人工智能与Python程序设计-写入.txt', 'w') # 文件对象的创建与打开
file_write.writelines(['人工智能',' ','Python程序设计'])   # 文件写入
file_write.close()   # 文件关闭
file_read = open('人工智能与Python程序设计-写入.txt', 'r')  
print(file_read.read())
file_read.close()
# Out:
# 人工智能 Python程序设计

# %%
file_write = open('人工智能与Python程序设计-写入.txt', 'w')  # 文件对象的创建与打开，覆盖写
file_write.writelines(['人工智能',' ','Python程序设计', '\n', '人工智能与Python程序设计'])
file_write.close()
file_read = open('人工智能与Python程序设计-写入.txt', 'r')
print(file_read.read())
file_read.close()
# Out:
# 人工智能 Python程序设计
# 人工智能与Python程序设计

# %%
file_write = open('人工智能与Python程序设计-写入.txt', 'a') # 文件对象的创建与打开，追加写
file_write.writelines(['\n', '人工智能与Python程序设计', ' ', '第一课'])
file_write.close()
file_read = open('人工智能与Python程序设计-写入.txt', 'r')
print(file_read.read())
file_read.close()
# Out:
# 人工智能 Python程序设计
# 人工智能与Python程序设计
# 人工智能与Python程序设计 第一课

# %%
with open('人工智能与Python程序设计-写入.txt', 'w') as f: 
    f.write('人工智能与Python程序设计 第一课')

with open('人工智能与Python程序设计-写入.txt', 'r') as f:
    print(f.read())
# Out:
# 人工智能与Python程序设计 第一课

# %%
file_write = open('人工智能与Python程序设计-写入.txt', 'w')  # 文件对象的创建与打开，覆盖写
file_write.write('人工智能与Python程序设计 第一课')
file_write.close()
file_read = open('人工智能与Python程序设计-写入.txt', 'r')
print(file_read.read())
file_read.close()
# Out:
# 人工智能与Python程序设计 第一课

# %%
ls = []
with open('imagenet.csv', 'r') as f: # csv文件对象的创建与打开
    for line in f: # csv文件逐行读取
        line=line.replace("\n", "") # 去除每行末尾的回车符’\n'
        ls.append(line.split(",")) # 用逗号’,‘分隔元素
print(ls)
# Out:
# [['Error rate', 'Gflops', 'Env Cost(CO2)', 'Economic Cost($)'], ['11.50%', '10^14', '10^6', '10^6'], ['5%', '10^19', '10^10', '10^11'], ['1%', '10^28', '10^20', '10^20']]

# %%
import csv
with open('imagenet.csv')as f: # csv文件对象的创建与打开
    f_csv = csv.reader(f) # csv文件读取
    for row in f_csv: # 逐行获取
        print(row)
# Out:
# ['Error rate', 'Gflops', 'Env Cost(CO2)', 'Economic Cost($)']
# ['11.50%', '10^14', '10^6', '10^6']
# ['5%', '10^19', '10^10', '10^11']
# ['1%', '10^28', '10^20', '10^20']

# %%
import csv
with open('imagenet.csv', 'r') as f:
    f_csv = csv.reader(f)
    for row in f_csv:  # 对当前文件逐行获取
        items = ""
        for item in row:  # 对当前行逐元素获取
            items += "{}\t".format(item)   # ’\t‘制表符
        print(items)
# Out:
# Error rate	Gflops	Env Cost(CO2)	Economic Cost($)
# 11.50%	10^14	10^6	10^6
# 5%	10^19	10^10	10^11
# 1%	10^28	10^20	10^20

# %%
import csv

headers = ['Error rate', 'Gflops', 'Env Cost(CO2)', 'Economic Cost($)']
rows = [['11.50%', '10^14', '10^6', '10^6'],
        ['5%', '10^19', '10^10', '10^11'],
        ['1%', '10^28', '10^20', '10^20']]
os.listdir()
with open('imagenet-write.csv','w')as f:  # csv文件对象的创建与打开
    f_csv = csv.writer(f)    # 创建csv文件的写对象
    f_csv.writerow(headers)  # 写入二维数据的第一行
    f_csv.writerows(rows)    # 写入二维数据的剩余行
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ca30de907057> in <module>
#       5         ['5%', '10^19', '10^10', '10^11'],
#       6         ['1%', '10^28', '10^20', '10^20']]
# ----> 7 os.listdir()
#       8 with open('imagenet-write.csv','w')as f:  # csv文件对象的创建与打开
#       9     f_csv = csv.writer(f)    # 创建csv文件的写对象
#
# NameError: name 'os' is not defined

# %%
import csv

headers = ['Error rate', 'Gflops', 'Env Cost(CO2)', 'Economic Cost($)']
rows = [  # head中key对应的value数值
        {'Error rate':'11.50%', 'Gflops':'10^14', 'Env Cost(CO2)':'10^6', 'Economic Cost($)':'10^6'},
        {'Error rate':'5%', 'Gflops':'10^19', 'Env Cost(CO2)':'10^10', 'Economic Cost($)':'10^11'},
        {'Error rate':'1%', 'Gflops':'10^28', 'Env Cost(CO2)':'10^20', 'Economic Cost($)':'10^20'}
    ]

with open('imagenet.csv','w',newline='')as f:
    f_csv = csv.DictWriter(f,headers)  # 创建csv文件的字典写对象
    f_csv.writeheader()   # 写入二维数据的第一行
    f_csv.writerows(rows) # 利用字典key-value对应关系，写入二维数据的剩余行

# %%
import os
os.path.abspath('.')
# Out:
# 'd:\\Vault\\school\\junior_last\\python 与人工智能\\python与人工智能-代码\\第4周第2次'

# %%
os.path.join('/Users/dtao/Documents/course/Python/代码数据/第四周第2次','PythonAI')
# Out:
# '/Users/dtao/Documents/course/Python/代码数据/第四周第2次\\PythonAI'

# %%
os.listdir() # 遍历当前目录下的文件，并返回条目名称组成的列表
# Out:
# ['.ipynb_checkpoints',
#  'imagenet.csv',
#  'IO编程.ipynb',
#  '人工智能与Python程序设计-写入.txt',
#  '人工智能与Python程序设计.txt',
#  '编码测试.py']

# %%
#os.mkdir(os.path.join('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI','os_module'))
#os.listdir('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI')

#这里是使用.listdir删除文件夹

# %%
os.rmdir(os.path.join('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI','os_module'))
os.listdir('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI')
# Out:
# []

# %%
os.path.split('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI')
# Out:
# ('/Users/dtao/Documents/course/Python/代码数据/第四周第2次', 'PythonAI')

# %%
os.path.splitext('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI')
# Out:
# ('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/PythonAI', '')

# %%
os.path.splitext('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/IO编程.ipynb')
# Out:
# ('/Users/dtao/Documents/course/Python/代码数据/第四周第2次/IO编程', '.ipynb')

# %%
[x for x in os.listdir('.') if os.path.splitext(x)[1]=='.txt']

#读取当前文件夹下的所有文档
# Out:
# ['人工智能与Python程序设计.txt', '人工智能与Python程序设计-写入.txt']

# %%
import os
import shutil

def organize_folder(folder):
    if not os.path.isdir(folder):
        print("错误：路径不存在或不是文件夹")
        return

    # 分类规则（扩展名 -> 目标子文件夹名）使用字典进行映射对应
    rule = {
        '.jpg': 'images', '.jpeg': 'images', '.png': 'images', '.gif': 'images',
        '.txt': 'docs', '.docx': 'docs', '.pdf': 'docs',
        '.py': 'code', '.java': 'code', '.js': 'code', '.html': 'code',
        '.zip': 'zips', '.rar': 'zips', '.7z': 'zips',
        '.ppt':'ppt','.pptx':'ppt'
    }

    # 收集待移动的文件
    files_to_move = []  # 列表元素: (原路径, 目标文件夹名)
    ext_set = set()

    for item in os.listdir(folder):
        src = os.path.join(folder, item)
        if not os.path.isfile(src):
            continue
        _, ext = os.path.splitext(item)
        ext = ext.lower()
        ext_set.add(ext)

        # 确定分类，默认进入 'others'
        target_sub = rule.get(ext, 'others')
        files_to_move.append((src, target_sub))

    # 输出统计
    print(f"共扫描文件数：{len(files_to_move)}")
    print(f"出现的扩展名：{ext_set}\n")

    # 移动文件
    for src, target_sub in files_to_move:
        target_dir = os.path.join(folder, target_sub)
        os.makedirs(target_dir, exist_ok=True)

        filename = os.path.basename(src)
        dst = os.path.join(target_dir, filename)

        # 重名处理
        if os.path.exists(dst):
            base, ext = os.path.splitext(filename)
            count = 1
            while os.path.exists(os.path.join(target_dir, f"{base}({count}){ext}")):
                count += 1
            dst = os.path.join(target_dir, f"{base}({count}){ext}")

        os.rename(src, dst)
        #shutil.move(src, dst)
        print(f"移动：{src} -> {dst}")

    print("\n整理完成！")

if __name__ == "__main__":
    #path = input("请输入文件夹路径：").strip()
    path = "./example_data"
    organize_folder(path)
# Out:
# 共扫描文件数：4
# 出现的扩展名：{'.py', '.txt', '.csv', '.pptx'}
#
# 移动：./example_data\file_tidy.py -> ./example_data\code\file_tidy.py
# 移动：./example_data\imagenet.csv -> ./example_data\others\imagenet.csv
# 移动：./example_data\人工智能与Python程序设计-写入.txt -> ./example_data\docs\人工智能与Python程序设计-写入.txt
# 移动：./example_data\第1周第2次-初识Python.pptx -> ./example_data\others\第1周第2次-初识Python.pptx
#
# 整理完成！
