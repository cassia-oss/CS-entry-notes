# %%
scores = [
    [80, 90, 85],
    [70, 75, 78],
    [88, 92, 95],
    [60, 65, 70],
    [95, 90, 98]
]

# %%
import numpy as np
arr = np.array(scores)
print(arr.shape)
print(arr.ndim)
# Out:
# (5, 3)
# 2

# %%
print("第1个学生全部成绩:", arr[0, :])
print("所有学生Python成绩:", arr[:, 0])
print("第2到第4个学生的Math和AI成绩:")
print(arr[1:4, 1:3])
print("第3个学生AI成绩:", arr[2, 2])
# Out:
# 第1个学生全部成绩: [80 90 85]
# 所有学生Python成绩: [80 70 88 60 95]
# 第2到第4个学生的Math和AI成绩:
# [[75 78]
#  [92 95]
#  [65 70]]
# 第3个学生AI成绩: 95
